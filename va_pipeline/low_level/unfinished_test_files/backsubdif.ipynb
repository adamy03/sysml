# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('rgb_data.csv')
#Convert x axis to seconds
df['Frame'] = df['Frame'] / 25
df.rename(columns={'Frame': 'Seconds'}, inplace=True)
# Print the DataFrame
print(df)
# Out:
#      Seconds  RGB Sum   Pixel Sum
# 0       0.00      NaN    424957.0
# 1       0.04      NaN   8200160.0
# 2       0.08      NaN  10860586.0
# 3       0.12      NaN   7314800.0
# 4       0.16      NaN  10336538.0
# ..       ...      ...         ...
# 144     5.76      NaN   6375784.0
# 145     5.80      NaN   6853467.0
# 146     5.84      NaN   7078118.0
# 147     5.88      NaN   7257163.0
# 148     5.92      NaN   6955920.0
#
# [149 rows x 3 columns]

# %%
#Convert x axis to seconds
df['Frame'] = df['Frame'] / 25
df.rename(columns={'Frame': 'Seconds'}, inplace=True)

# %%
df.plot(x='Seconds', y='Pixel Sum')
# Large Slow KNN
# Out:
# <AxesSubplot:xlabel='Seconds'>

# %%
df.plot(x='Seconds', y='Pixel Sum')
# Large Slow MOG2
# Out:
# <AxesSubplot:xlabel='Seconds'>

# %%
df.plot(x='Seconds', y='Pixel Sum')
# Large Fast KNN
# Out:
# <AxesSubplot:xlabel='Seconds'>

# %%
df.plot(x='Seconds', y='Pixel Sum')
# Large Fast MOG2
# Out:
# <AxesSubplot:xlabel='Seconds'>

# %%
df.plot(x='Seconds', y='Pixel Sum')
# Large Fast Frame dif on backsub
# Out:
# <AxesSubplot:xlabel='Seconds'>

# %%
df.plot(x='Seconds', y='Pixel Sum')
# largeslow MOG2 background
# Out:
# <AxesSubplot:xlabel='Seconds'>

# %%
df.plot(x='Seconds', y='Pixel Sum')
# largeslow KNN background
# Out:
# <AxesSubplot:xlabel='Seconds'>
